# %% [markdown]
# <a href="https://colab.research.google.com/github/jas-tang/datasci_1_loading/blob/main/HHA507.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Loading Packages

# %%
import pandas as pd

# %% [markdown]
# # Effects of COVID-19 on Hospital Utilization Trends CSV File
# Due to the COVID-19 pandemic, hospitals across the state experienced a significant decrease in various healthcare activities such as inpatient discharges, emergency department visits, and ambulatory surgeries. These datasets encompass monthly encounter counts and in-hospital mortality data within these three healthcare settings. This only shows the first 10 rows.
#
# ---
#
# ## Column Information
# * Setting refers to the location in the hospital where encounters occured
# * System refers to the organization that share ownership for a contracting relationship for payment and service delivery
# * Facility refers to the individual hospital care facility, clinic or surgery center
# * Count refers to the monthly total of patient encounters
# * Date refers to the month and year of patient encounters

# %%
covid19 = pd.read_csv("/content/sample_data/hospital-utilization-trends.csv")
#Display the first 10 rows
result = covid19.head(10)
print("First 10 rows of the DataFrame:")
result
# Out:
# First 10 rows of the DataFrame:
#               Setting                    System                 Facility Name  \
# 0  Ambulatory Surgery  Adventist Health Systems  Adventist Health and Rideout
# 1  Ambulatory Surgery  Adventist Health Systems  Adventist Health and Rideout
# 2  Ambulatory Surgery  Adventist Health Systems  Adventist Health and Rideout
# 3  Ambulatory Surgery  Adventist Health Systems  Adventist Health and Rideout
# 4  Ambulatory Surgery  Adventist Health Systems  Adventist Health and Rideout
# 5  Ambulatory Surgery  Adventist Health Systems  Adventist Health and Rideout
# 6  Ambulatory Surgery  Adventist Health Systems  Adventist Health and Rideout
# 7  Ambulatory Surgery  Adventist Health Systems  Adventist Health and Rideout
# 8  Ambulatory Surgery  Adventist Health Systems  Adventist Health and Rideout
# 9  Ambulatory Surgery  Adventist Health Systems  Adventist Health and Rideout
#
#      Date  Count
# 0  Jan-18    253
# 1  Feb-18    226
# 2  Mar-18    283
# 3  Apr-18    230
# 4  May-18    276
# 5  Jun-18    271
# 6  Jul-18    258
# 7  Aug-18    304
# 8  Sep-18    248
# 9  Oct-18    319

# %% [markdown]
# # ZIP Code-level data on daily temperature from 2000-2017 CSV File
# The data comprises (1) daily average temperatures at the ZIP code level spanning from 2000 to 2017, (2) daily counts of Medicare hospitalizations due to cardiovascular disease at the ZIP code level during the same period, and (3) urban heat island intensity (UHII) weighted by population at the ZIP code level. The dataset has 9,917 ZIP codes situated within the urban centers of 120 metropolitan statistical areas across the contiguous United States. This only shows the first 10 rows.
#
# ---
#
# ## Column information
#
# * MSA is the Code for metropolitan statistical area (MSA) that the ZIP code belongs to
# * ZIP is the ZIP code data corresponds to
# * UHII.Wght is the urban heat island intensity weighted

# %%
zipcodetemp = pd.read_csv("/content/sample_data/ZIP_Code_daily_temperature.csv")
#Display the first 10 rows
result = zipcodetemp.head(10)
print("First 10 rows of the DataFrame:")
result
# Out:
# First 10 rows of the DataFrame:
#      MSA   ZIP  UHII.Wght
# 0  44140  1001   2.025531
# 1  44140  1002  -0.097416
# 2  44140  1004   1.839478
# 3  44140  1007  -2.422540
# 4  44140  1013   3.762109
# 5  44140  1014   2.520789
# 6  44140  1020   4.385379
# 7  44140  1021   3.450106
# 8  44140  1022   4.873689
# 9  44140  1027  -0.434837

# %% [markdown]
# # California Statewide Inpatient Mortality Rates CSV File
# The dataset includes risk-adjusted mortality rates, as well as the number of deaths and cases for six medical conditions (Acute Stroke, Acute Myocardial Infarction, Heart Failure, Gastrointestinal Hemorrhage, Hip Fracture, and Pneumonia) and six medical procedures (Abdominal Aortic Aneurysm Repair, Carotid Endarterectomy, Craniotomy, Esophageal Resection, Pancreatic Resection, Percutaneous Coronary Intervention) performed in hospitals across California. This only shows the first 10 rows.
#
# ---
#
# ## Column Information
# * Year refers to the time the procedure took place
# * Hospital refers to the type of hospital
# * Procedure/Condition refers to the event that took place
# * Risk Adjusted Mortality Rate refers to the adjustment of observed mortality
# rate after accounting for existing healh problems
# * Number of deaths refer to the number of patients that died in california due to the procedure/condition
# * Nubmer of cases refers to the number of patients that had the specific medical procedure or condition

# %%
calimortalityrates = pd.read_csv("/content/sample_data/california_inpatient_mortality.csv")
#Display the first 10 rows
result = calimortalityrates.head(10)
print("First 10 rows of the DataFrame:")
result
# Out:
# First 10 rows of the DataFrame:
#    YEAR   HOSPITAL       Procedure/Condition  Risk Adjuested Mortality Rate  \
# 0  2012  STATEWIDE                       PCI                            2.5
# 1  2012  STATEWIDE                 Pneumonia                            4.0
# 2  2012  STATEWIDE             GI Hemorrhage                            2.1
# 3  2012  STATEWIDE          Pancreatic Other                            2.8
# 4  2012  STATEWIDE                       AMI                            6.3
# 5  2012  STATEWIDE     Espophageal Resection                            5.7
# 6  2012  STATEWIDE     Acute Stroke Ischemic                            5.3
# 7  2012  STATEWIDE  Acute Stroke Hemorrhagic                           23.0
# 8  2012  STATEWIDE              Hip Fracture                            2.3
# 9  2012  STATEWIDE      Pancreatic Resection                            2.4
#
#    # of Deaths  # of Cases
# 0         1015       40790
# 1         2606       64400
# 2         1024       47893
# 3           22         794
# 4         2938       46663
# 5           22         387
# 6         2150       40900
# 7         2432       10576
# 8          552       23774
# 9           41        1724

# %% [markdown]
# # FDA Data Inventory JSON File
# This data set includes all the FDA datasets provided by the U.S. Food and Drug Administration as of 2020. This only shows the first 10 rows.
#
# ---
#
# ## Column Information
#
# * Conforms to refers to the website location
# * As_of_date refers to the date it was last updated
# * dataset refers to the dataset information

# %%
fda = pd.read_json("/content/sample_data/fda.json")
#Display the first 10 rows
result = fda.head(10)
print("First 10 rows of the DataFrame:")
result
# Out:
#                                       conformsTo                as_of_date  \
# 0  https://project-open-data.cio.gov/v1.1/schema  Tuesday, August 18, 2015
# 1  https://project-open-data.cio.gov/v1.1/schema  Tuesday, August 18, 2015
# 2  https://project-open-data.cio.gov/v1.1/schema  Tuesday, August 18, 2015
# 3  https://project-open-data.cio.gov/v1.1/schema  Tuesday, August 18, 2015
# 4  https://project-open-data.cio.gov/v1.1/schema  Tuesday, August 18, 2015
# 5  https://project-open-data.cio.gov/v1.1/schema  Tuesday, August 18, 2015
# 6  https://project-open-data.cio.gov/v1.1/schema  Tuesday, August 18, 2015
# 7  https://project-open-data.cio.gov/v1.1/schema  Tuesday, August 18, 2015
# 8  https://project-open-data.cio.gov/v1.1/schema  Tuesday, August 18, 2015
# 9  https://project-open-data.cio.gov/v1.1/schema  Tuesday, August 18, 2015
#
#                                              dataset
# 0  {'accessLevel': 'public', 'bureauCode': ['009:...
# 1  {'accessLevel': 'public', 'bureauCode': ['009:...
# 2  {'accessLevel': 'public', 'bureauCode': ['009:...
# 3  {'accessLevel': 'public', 'bureauCode': ['009:...
# 4  {'accessLevel': 'public', 'bureauCode': ['009:...
# 5  {'accessLevel': 'public', 'bureauCode': ['009:...
# 6  {'accessLevel': 'public', 'bureauCode': ['009:...
# 7  {'accessLevel': 'public', 'bureauCode': ['009:...
# 8  {'accessLevel': 'public', 'bureauCode': ['009:...
# 9  {'accessLevel': 'public', 'bureauCode': ['009:...

# %% [markdown]
# # HHS Enterprise Data Inventory JSON File
# The Enterprise Data Inventory (EDI) is the comprehensive inventory listing of agency data resources including public, restricted public, and non-public datasets. This dataset was last updated in 2015. This only shows the first 10 rows.
#
# ---
#
# ## Column information
# * Conforms to refers to the website location
# * Described by refers to where the data is detailed
# * Context refers to where the data is detailed
# * Type refers to the data type categorized
# * Dataset refers to the data itself

# %%
hsa = pd.read_json("/content/sample_data/hsa.json")
#Display the first 10 rows
result = hsa.head(10)
print("First 10 rows of the DataFrame:")
result
# Out:
# First 10 rows of the DataFrame:
#                                       conformsTo  \
# 0  https://project-open-data.cio.gov/v1.1/schema
# 1  https://project-open-data.cio.gov/v1.1/schema
# 2  https://project-open-data.cio.gov/v1.1/schema
# 3  https://project-open-data.cio.gov/v1.1/schema
# 4  https://project-open-data.cio.gov/v1.1/schema
# 5  https://project-open-data.cio.gov/v1.1/schema
# 6  https://project-open-data.cio.gov/v1.1/schema
# 7  https://project-open-data.cio.gov/v1.1/schema
# 8  https://project-open-data.cio.gov/v1.1/schema
# 9  https://project-open-data.cio.gov/v1.1/schema
#
#                                          describedBy  \
# 0  https://project-open-data.cio.gov/v1.1/schema/...
# 1  https://project-open-data.cio.gov/v1.1/schema/...
# 2  https://project-open-data.cio.gov/v1.1/schema/...
# 3  https://project-open-data.cio.gov/v1.1/schema/...
# 4  https://project-open-data.cio.gov/v1.1/schema/...
# 5  https://project-open-data.cio.gov/v1.1/schema/...
# 6  https://project-open-data.cio.gov/v1.1/schema/...
# 7  https://project-open-data.cio.gov/v1.1/schema/...
# 8  https://project-open-data.cio.gov/v1.1/schema/...
# 9  https://project-open-data.cio.gov/v1.1/schema/...
#
#                                             @context         @type  \
# 0  https://project-open-data.cio.gov/v1.1/schema/...  dcat:Catalog
# 1  https://project-open-data.cio.gov/v1.1/schema/...  dcat:Catalog
# 2  https://project-open-data.cio.gov/v1.1/schema/...  dcat:Catalog
# 3  https://project-open-data.cio.gov/v1.1/schema/...  dcat:Catalog
# 4  https://project-open-data.cio.gov/v1.1/schema/...  dcat:Catalog
# 5  https://project-open-data.cio.gov/v1.1/schema/...  dcat:Catalog
# 6  https://project-open-data.cio.gov/v1.1/schema/...  dcat:Catalog
# 7  https://project-open-data.cio.gov/v1.1/schema/...  dcat:Catalog
# 8  https://project-open-data.cio.gov/v1.1/schema/...  dcat:Catalog
# 9  https://project-open-data.cio.gov/v1.1/schema/...  dcat:Catalog
#
#                                              dataset
# 0  {'@type': 'dcat:Dataset', 'description': '<p>C...
# 1  {'@type': 'dcat:Dataset', 'description': '<p><...
# 2  {'@type': 'dcat:Dataset', 'description': '<p><...
# 3  {'@type': 'dcat:Dataset', 'description': '<p><...
# 4  {'@type': 'dcat:Dataset', 'description': '<p><...
# 5  {'@type': 'dcat:Dataset', 'description': '<p><...
# 6  {'@type': 'dcat:Dataset', 'description': '<p>T...
# 7  {'@type': 'dcat:Dataset', 'description': '<p>T...
# 8  {'@type': 'dcat:Dataset', 'description': '<p>T...
# 9  {'@type': 'dcat:Dataset', 'description': '<p>T...

# %% [markdown]
# # Employee Information JSON File
# This dataset was randomly generated using a JSON file generator. The purpose behind it this is to have a dataset on employee data.
#
#
# ---
#
#
# ## Column Information
# * ID refers to the employee ID
# * GUID refers to a globally unique identifier for the device they are using
# * isActive refers to if they are an active employee
# * Company refers to what organization they are emoployed to
# * Email refers to their contact for their email
# * Phone refers to their contact for their phone number
# * Address refers to their current state of residence
# * Registered refers to the date and time they were registered into the system

# %%
info = pd.read_json("/content/sample_data/employee.json")
info
# Out:
#                         _id  index                                  guid  \
# 0  64f40fb0b154fdfb407e4048      0  02a4e41d-18c5-427e-8e24-e9d8ee035fd9
# 1  64f40fb03bdf26dccbfca16b      1  8d3b5a62-9669-4331-b485-d74b880ecbb0
# 2  64f40fb005cec9c8747cf1a4      2  14221cdd-deff-404f-ac12-ff6034598ad4
# 3  64f40fb0331268dafee43195      3  6d105fe7-7181-4318-9d0d-2c06880fd4e4
# 4  64f40fb05f23e2129934d20f      4  c8d20194-642c-4300-a9d9-acfc2bbfd642
# 5  64f40fb0070b19d8ea9d5b6b      5  e0e72019-903a-4a5c-84d9-d63a299125d3
# 6  64f40fb0dec4736dc2aeeae4      6  e2db3a6b-e75b-4003-af3d-d33fc7cb8e08
# 7  64f40fb0216f241e1eb336e0      7  21609f05-d1e0-4cfb-8aa3-857778219911
# 8  64f40fb006925443ad384533      8  b4b85e8f-dada-43da-b63a-fb6e8d83ffbf
# 9  64f40fb08773366d1750315e      9  c3617704-381f-45ae-b895-20c4884db991
#
#    isActive  age  ...    company                           email  \
# 0     False   31  ...   WRAPTURE         vilmaayala@wrapture.com
# 1     False   34  ...   TERRAGEN       waltersroach@terragen.com
# 2      True   20  ...     CINCYR          spearsfloyd@cincyr.com
# 3      True   38  ...   EXOSPEED       gordonbecker@exospeed.com
# 4      True   25  ...      ZINCA           nadiageorge@zinca.com
# 5      True   30  ...  CRUSTATIA  gonzalesmcdaniel@crustatia.com
# 6      True   33  ...      UPDAT         gertrudemyers@updat.com
# 7      True   31  ...   VISUALIX        butlerbeard@visualix.com
# 8     False   22  ...   SNOWPOKE       stellaparker@snowpoke.com
# 9      True   35  ...     NORSUL          trangoodman@norsul.com
#
#                phone                                           address  \
# 0  +1 (922) 498-3251          715 Amber Street, Sedley, Delaware, 7218
# 1  +1 (990) 451-2890   404 Herkimer Street, Saddlebrooke, Nevada, 7824
# 2  +1 (954) 539-2943  841 Perry Terrace, Stewartville, Tennessee, 9625
# 3  +1 (958) 568-3371       106 Tehama Street, Caroleen, Virginia, 6574
# 4  +1 (871) 548-3720      495 Barlow Drive, Hollymead, Louisiana, 1011
# 5  +1 (968) 569-2370         267 Tilden Avenue, Detroit, Indiana, 8596
# 6  +1 (879) 435-3436     550 Boynton Place, Brookfield, Oklahoma, 3567
# 7  +1 (818) 415-3421            844 Sullivan Place, Odessa, Ohio, 7681
# 8  +1 (948) 420-3944      946 Exeter Street, Gambrills, Wisconsin, 939
# 9  +1 (873) 473-3289             290 Post Court, Churchill, Palau, 753
#
#                    registered
# 0  2022-06-05T05:10:25 +04:00
# 1  2015-05-02T08:17:01 +04:00
# 2  2020-07-21T04:07:02 +04:00
# 3  2015-04-08T07:49:52 +04:00
# 4  2022-07-24T05:44:20 +04:00
# 5  2019-12-03T04:18:11 +05:00
# 6  2017-10-01T11:15:18 +04:00
# 7  2014-02-12T11:03:01 +05:00
# 8  2022-08-21T12:42:04 +04:00
# 9  2017-09-06T04:12:05 +04:00
#
# [10 rows x 13 columns]

# %% [markdown]
# # Medically Undeserved Areas/Populations XLSX File
# This dataset shows the geographic components that define a metropolitan statistical area at a specific point in time of metropolitan statistical areas and associated statistical areas established by the Office of Management and Budget OMB since 2013.
#
# ---
# ## Column Information
# * Attribute name refers to the type of code
# * Physical Column name refers to the ID to correlates with the attribute name
# * User Friend Name refers to a human readable to the attribute name
# * Data Restriction refers to if the data is available to the public
# * Organization refers to the ownership of the data
# * Update Frequency refers to how often the data is updated
# * Business Rule refers to if the data has any requirements
# * HDW Transformation refers to additional information about the data
# * Valid Values refers to additional coding rules to the data
# * Definition Update Date refers to the last time the data was updated

# %%
mua = pd.read_excel("/content/sample_data/MUA_DATAMART_METADATA.XLSX")
#Display first 10 rows
result = mua.head(10)
print("First 10 rows of the DataFrame:")
result
# Out:
# First 10 rows of the DataFrame:
#                                       Attribute Name  Physical Column Name  \
# 0    Geocoding Artifact Object Identification Number              OBJECTID
# 1                        Congressional District Name          CONG_DIST_NM
# 2                Geocoding Artifact Feature Geometry                 SHAPE
# 3                                    State FIPS Code         STATE_FIPS_CD
# 4                                         State Name              STATE_NM
# 5                                  HHS Region Number  REGION_ROMAN_NUMERAL
# 6             U.S. Congressional Representative Name     REPRESENTATIVE_NM
# 7                              U.S. Senator Name (2)         US_SENATE_NM2
# 8                  Data Warehouse Record Create Date   DW_RECORD_CREATE_DT
# 9  County or County Equivalent Federal Informatio...        COUNTY_FIPS_CD
#
#                                  User Friendly Names  \
# 0  Geocoding Artifact Object Identification Numbe...
# 1  Congressional District Name; Cong. District; C...
# 2  Geocoding Artifact Feature Geometry; Feature G...
# 3  State FIPS Code; State Federal Information Pro...
# 4  State Name; Component State; Component State N...
# 5           HHS Region Number; Region; Region Number
# 6  U.S. Congressional Representative Name; Congre...
# 7  U.S. Senator Name (2); Name of U.S. Senator; N...
# 8  Data Warehouse Record Create Date; Data As-of-...
# 9  County or County Equivalent Federal Informatio...
#
#                                           Definition Data Restriction  \
# 0  This attribute represents the table unique, in...           Public
# 1  This attribute represents the name of the U.S....           Public
# 2  This attribute represents the geometry of the ...           Public
# 3  This attribute represents the State Federal In...           Public
# 4  This attribute represents the state or territo...           Public
# 5  This attribute represents the Roman numeral po...           Public
# 6  This attribute represents the name of the Cong...           Public
# 7  This attribute represents the name of one of t...           Public
# 8  This attribute represents the date on which th...           Public
# 9  This attribute represents the numeric characte...           Public
#
#                                         Organization Update Frequency  \
# 0                                HRSA Data Warehouse      As Required
# 1                      U.S. House of Representatives      As Required
# 2                                HRSA Data Warehouse      As Required
# 3  National Institute of Standards and Technology...      As Required
# 4  National Institute of Standards and Technology...      As Required
# 5  U.S. Department of Health and Human Services (...      As Required
# 6                      U.S. House of Representatives          Monthly
# 7                                        U.S. Senate          Monthly
# 8                                HRSA Data Warehouse      As Required
# 9  National Institute of Standards and Technology...      As Required
#
#        Data Type                             Business Rule / Format  \
# 0            int                                              None.
# 1   nvarchar(50)                                              None.
# 2       geometry                                              None.
# 3    nvarchar(2)                                              None.
# 4    varchar(50)                                              None.
# 5     varchar(4)                                              None.
# 6  nvarchar(100)                                              None.
# 7   varchar(100)  The District of Columbia and the U.S. territor...
# 8      datetime2                                              None.
# 9        char(3)                                              None.
#
#                                   HDW Transformation  \
# 0  This attribute is a common element which may b...
# 1  (1) For states with two or more representative...
# 2  (1) If the data provided from the original sou...
# 3  This attribute is a common element which may b...
# 4  This attribute is a common element which may b...
# 5  This attribute is a common element which may b...
# 6  This attribute is a common element which may b...
# 7  This attribute is a common element which may b...
# 8  (1) System date on which the data set was refr...
# 9  This attribute is a common element which may b...
#
#                                         Valid Values Definition Update Date
# 0  Expected values are integers. For example, 1; ...             2020/08/15
# 1  Expected values are text strings for Congressi...             2016/05/27
# 2  Expected values are geometry type values. For ...             2018/08/30
# 3  Expected values are two character numeric text...             2020/08/15
# 4  Expected values are alphabetic text strings re...             2020/08/15
# 5  Expected values are numeric strings consisting...             2016/05/27
# 6  Expected values are text strings containing th...             2016/05/27
# 7  Expected values are text strings containing th...             2018/03/16
# 8  Expected values are date time where the time i...             2022/07/19
# 9  Expected values are numeric text strings, exac...             2020/08/15

# %% [markdown]
# # Organ Transplant Statistics XLSX File
# This dataset shows the numbers of organ transplants performed over years and is updated by the Health Resources and Services Administrastion annualy. This dataset is from 2018.
#
# ---
#
# ## Column Information
# * Attribute name refers to type of code
# * Physical Column name refers to the ID to correlates with the attribute name
# * User Friend Name refers to a human readable to the attribute name
# * Data Restriction refers to if the data is available to the public
# * Organization refers to the ownership of the data
# * Update Frequency refers to how often the data is updated
# * Business Rule refers to if the data has any requirements
# * HDW Transformation refers to additional information about the data
# * Valid Values refers to additional coding rules to the data
# * Definition Update Date refers to the last time the data was updated

# %%
org = pd.read_excel("/content/sample_data/ORG_OTS_DATAMART_METADATA.XLSX")
#Display 10 rows
result = org.head(10)
print("First 10 rows of the DataFrame:")
result
# Out:
# First 10 rows of the DataFrame:
#                       Attribute Name Physical Column Name  \
# 0                    State FIPS Code        STATE_FIPS_CD
# 1                         State Name             STATE_NM
# 2  Data Warehouse Record Create Date  DW_RECORD_CREATE_DT
# 3                    HHS Region Name            REGION_NM
# 4                    HHS Region Code            REGION_CD
# 5                 State Abbreviation           STATE_ABBR
# 6                     Geography Code         Geography_Cd
# 7                     Geography Type        Geography_Typ
# 8              Technical Data Source          Data_Source
# 9                        Time Period          TIME_PERIOD
#
#                                  User Friendly Names  \
# 0  State FIPS Code; State Federal Information Pro...
# 1  State Name; Component State; Component State N...
# 2  Data Warehouse Record Create Date; Data As-of-...
# 3  HHS Region Name; Component HHS Region; HHS Reg...
# 4                       HHS Region Code; Region Code
# 5    State Abbreviation; State; State Code; State_Cd
# 6  Geography Code; Census Tract Code; CSD FIPS Co...
# 7                                     Geography Type
# 8                 Technical Data Source; Data Source
# 9          Time Period; Fact Sheet Fiscal Year Value
#
#                                           Definition Data Restriction  \
# 0  This attribute represents the State Federal In...           Public
# 1  This attribute represents the state or territo...           Public
# 2  This attribute represents the date on which th...           Public
# 3  This attribute represents the formal name for ...           Public
# 4  This attribute represents the U.S. Department ...           Public
# 5  This attribute represents the U.S. Postal Serv...           Public
# 6  This attribute represents the code that unique...           Public
# 7  This attribute represents the geography type n...           Public
# 8  This attribute represents the textual descript...           Public
# 9  This attribute represents the time period to a...           Public
#
#                                         Organization Update Frequency  \
# 0  National Institute of Standards and Technology...      As Required
# 1  National Institute of Standards and Technology...      As Required
# 2                                HRSA Data Warehouse      As Required
# 3  U.S. Department of Health and Human Services (...      As Required
# 4  U.S. Department of Health and Human Services (...      As Required
# 5                                HRSA Data Warehouse      As Required
# 6                                HRSA Data Warehouse      As Required
# 7                                HRSA Data Warehouse      As Required
# 8                                HRSA Data Warehouse      As Required
# 9                                HRSA Data Warehouse      As Required
#
#        Data Type                             Business Rule / Format  \
# 0        char(2)                                              None.
# 1    varchar(50)                                              None.
# 2  smalldatetime                                              None.
# 3    varchar(25)                                              None.
# 4        char(2)                                              None.
# 5        char(2)                                              None.
# 6    varchar(50)                                              None.
# 7    varchar(25)                                              None.
# 8   varchar(200)  (1) Datasets obtained by the Primary Care Serv...
# 9   varchar(100)                                              None.
#
#                                   HDW Transformation  \
# 0  This attribute is a common element which may b...
# 1  This attribute is a common element which may b...
# 2  (1) System date on which the data set was refr...
# 3  This attribute is a common element which may b...
# 4  This attribute is a common element which may b...
# 5  This attribute is a common element which may b...
# 6  (1) The geography codes have leading zeroes an...
# 7                                              None.
# 8      Updated as required depending on the dataset.
# 9  (1) This attribute is a common element which m...
#
#                                         Valid Values Definition Update Date
# 0  Expected values are two character numeric text...             2020/08/15
# 1  Expected values are alphabetic text strings re...             2020/08/15
# 2  Expected values are date time where the time i...             2022/07/19
# 3  Expected values are alphanumeric, proper case,...             2020/08/15
# 4  Expected values are two character numeric text...             2020/08/15
# 5  Expected values are two character alphabetic t...             2020/08/15
# 6  Expected values are 2, 4, 5, 10, 11, or 12 cha...             2022/07/19
# 7  Expected values are positive integers between ...             2022/07/19
# 8  Expected values are free-form alphanumeric tex...             2018/09/06
# 9  Expected values are alphanumeric text strings ...             2022/07/19

# %% [markdown]
# # Maltreatment Types of Victims XLSX File
# This dataset shows the number of maltreatment types that are counted by the U.S. Department of Health and Human services.
#
# ---
#
# * State refers to which area the maltreatment count was
# * Medical Neglect Only refers to the number of maltreatment types
# * Other only refers to maltreatment types that are not one of the codes in the NCANDS record
# * Physical Abuse Only refers to the maltreatment types counted as physical abuse
# * Psychological maltreatment only refers to maltreatment types counted as psychological abuse
# * Sexual Abuse only refers to the maltreatment types counted as sexual abuse
# * Sex trafficking only refers to the maltreatment types counted as sex trafficking
# * Neglect only refers to the maltreatment types counted as neglect
# * Physical abuse only percent refers to the percentage total of total maltreatment that are physical abuse
# * Psychological Maltreatment abuse only percent refers to the percentage total of total maltreatment that are Psychological Maltreatment
# * Sexual abuse only percent refers to the percentage total of total maltreatment that are Sexual abuse
# * Sex trafficking abuse only percent refers to the percentage total of total maltreatment that are Sex trafficking abuse
# * Unknown only percent refers to the percentage of the total maltreatment that are not counted

# %%
maltreatment = pd.read_excel("/content/sample_data/Maltreatment_Types_of_Victims.xlsx")
#Display only 10
result = maltreatment.head(10)
print("First 10 rows of the DataFrame:")
result
# Out:
# First 10 rows of the DataFrame:
#                   State  Medical Neglect Only  Neglect Only  Other Only  \
# 0               Alabama                  49.0          3380         NaN
# 1                Alaska                  37.0          1445         NaN
# 2               Arizona                   NaN         11332         NaN
# 3              Arkansas                1279.0          3421         1.0
# 4            California                   NaN         50799       117.0
# 5              Colorado                  80.0          9517         NaN
# 6           Connecticut                  87.0          4709         NaN
# 7              Delaware                   NaN           313       120.0
# 8  District of Columbia                   NaN          1492         NaN
# 9               Florida                 616.0         12893      8201.0
#
#    Physical Abuse Only  Psychological Maltreatment Only  Sexual Abuse Only  \
# 0                 5114                             16.0             1828.0
# 1                  111                            327.0              183.0
# 2                  682                              1.0              389.0
# 3                 1286                             25.0             1415.0
# 4                 2161                           2115.0             2264.0
# 5                  854                            126.0              990.0
# 6                  172                            599.0              181.0
# 7                  161                            404.0              121.0
# 8                  175                              NaN               45.0
# 9                 1742                            156.0             2354.0
#
#    Sex Trafficking Only  Unknown Only  Multiple Maltreatment Types  ...  \
# 0                   3.0           NaN                         1287  ...
# 1                   1.0           NaN                          955  ...
# 2                   NaN           NaN                          443  ...
# 3                   NaN           NaN                          995  ...
# 4                   NaN           NaN                         6659  ...
# 5                   NaN           9.0                          670  ...
# 6                   NaN           NaN                         2294  ...
# 7                   NaN           NaN                          129  ...
# 8                  14.0           NaN                          131  ...
# 9                   NaN           NaN                         6953  ...
#
#    Medical Neglect Only Percent  Neglect Only Percent  Other Only Percent  \
# 0                           0.4                  28.9                 NaN
# 1                           1.2                  47.2                 NaN
# 2                           NaN                  88.2                 NaN
# 3                          15.2                  40.6                 0.0
# 4                           NaN                  79.2                 0.2
# 5                           0.7                  77.7                 NaN
# 6                           1.1                  58.6                 NaN
# 7                           NaN                  25.1                 9.6
# 8                           NaN                  80.3                 NaN
# 9                           1.9                  39.2                24.9
#
#    Physical Abuse Only Percent  Psychological Maltreatment Only Percent  \
# 0                         43.8                                      0.1
# 1                          3.6                                     10.7
# 2                          5.3                                      0.0
# 3                         15.3                                      0.3
# 4                          3.4                                      3.3
# 5                          7.0                                      1.0
# 6                          2.1                                      7.4
# 7                         12.9                                     32.4
# 8                          9.4                                      NaN
# 9                          5.3                                      0.5
#
#    Sexual Abuse Only Percent  Sex Trafficking Only Percent  \
# 0                       15.7                           0.0
# 1                        6.0                           0.0
# 2                        3.0                           NaN
# 3                       16.8                           NaN
# 4                        3.5                           NaN
# 5                        8.1                           NaN
# 6                        2.3                           NaN
# 7                        9.7                           NaN
# 8                        2.4                           0.8
# 9                        7.2                           NaN
#
#    Unknown Only Percent  Multiple Maltreatment Types Percent  \
# 0                   NaN                                 11.0
# 1                   NaN                                 31.2
# 2                   NaN                                  3.4
# 3                   NaN                                 11.8
# 4                   NaN                                 10.4
# 5                   0.1                                  5.5
# 6                   NaN                                 28.5
# 7                   NaN                                 10.3
# 8                   NaN                                  7.1
# 9                   NaN                                 21.1
#
#    Total Victims Percent
# 0                  100.0
# 1                  100.0
# 2                  100.0
# 3                  100.0
# 4                  100.0
# 5                  100.0
# 6                  100.0
# 7                  100.0
# 8                  100.0
# 9                  100.0
#
# [10 rows x 21 columns]
